# %%
# %%
import pandas as pd

# Load feature data from parquet
df = pd.read_parquet("../data/visitor_features.parquet")

# Quick peek at the first 5 rows
df.head()
# Out:
#                         visitor_key     browser  os_name   region  has_signup  \
# 0  a03e6e1f880e7c684fccb71b9451a7e8  mobile_web      iOS  Alabama           0
# 1  95a936cbca6336e2df0f577f00056698  mobile_web      iOS  Alabama           0
# 2  ffebac852989f1b0b93050f222ec99bb  mobile_web      iOS  Alabama           0
# 3  fad773f668095988f35fbfffa32d4f03  mobile_web      iOS  Alabama           0
# 4  d2c9956f0079bd53370c5b14075bae61  mobile_web  Android  Alabama           0
#
#   test_engagement_state tests_taken_count_bucket tests_completed_count_bucket  \
# 0               No Test                        0                            0
# 1               No Test                        0                            0
# 2     Test Started Only                        1                            0
# 3     Test Started Only                        1                            0
# 4     Test Started Only                        1                            0
#
# ...

# %%
print(df['browser'].value_counts(dropna=False))
# Out:
# browser
# mobile_web     453122
# desktop_web     82269
# Name: count, dtype: int64

# %%
print(df['os_name'].value_counts(dropna=False))
# Out:
# os_name
# iOS            329050
# Android        147286
# Windows         31192
# macOS           14163
# Chrome OS        6661
# None             5491
# Linux            1356
# Ubuntu             97
# KAIOS              65
# PlayStation         8
# Tizen               5
# Nintendo            5
# HarmonyOS           3
# Chromecast          3
# Xbox                2
# Raspbian            2
# FreeBSD             1
# linux               1
# Name: count, dtype: int64

# %%
print(df['region'].value_counts(dropna=False))
# Out:
# region
# California              49361
# Texas                   47286
# Florida                 32456
# New York                30686
# Pennsylvania            22229
# Ohio                    21685
# North Carolina          20598
# Illinois                20491
# Georgia                 19638
# Michigan                18511
# Tennessee               14354
# Virginia                14225
# Washington              14207
# Indiana                 13424
# Arizona                 12344
# Missouri                10997
# Colorado                10505
# Maryland                10320
# New Jersey              10180
# Alabama                  9893
# Massachusetts            9607
# Minnesota                9532
# Kentucky                 8809
# Oregon                   8637
# Wisconsin                8261
# Oklahoma                 7706
# South Carolina           7580
# Louisiana                6735
# Utah                     6660
# Nevada                   5958
# ...

# %%
print(df['test_engagement_state'].value_counts(dropna=False))
# Out:
# test_engagement_state
# Test Completed       425185
# Test Started Only     77550
# No Test               32656
# Name: count, dtype: int64

# %%
print(df['tests_taken_count_bucket'].value_counts(dropna=False))
# Out:
# tests_taken_count_bucket
# 1      401457
# 2–3     65924
# 4+      35354
# 0       32656
# Name: count, dtype: int64

# %%
print(df['tests_completed_count_bucket'].value_counts(dropna=False))
# Out:
# tests_completed_count_bucket
# 1     366807
# 0     110206
# 2+     58378
# Name: count, dtype: int64

# %%
print(df['test_latency_bucket'].value_counts(dropna=False))
# Out:
# test_latency_bucket
# Immediate                 501436
# No Test                    32656
# Test Before First Seen       727
# After 24 Hours               195
# Within 1 Hour                159
# Within 6 Hours               146
# Within 24 Hours               72
# Name: count, dtype: int64

# %%
print(df['first_test_taken'].value_counts(dropna=False))
# Out:
# first_test_taken
# Gender Dysphoria                     59298
# Borderline Personality Disorder      50007
# PTSD                                 45923
# Depression                           44024
# Sex Addiction                        40123
# Bipolar Disorder                     35865
# Dissociative Identity Disorder       34842
# None                                 32656
# Sociopath                            28364
# Narcissistic Personality Disorder    26543
# Postpartum Depression                22849
# Schizophrenia                        21250
# Relationship Health                  14678
# Social Anxiety Disorder              10849
# Binge Eating Disorder                10559
# Adult ADHD                            9661
# Anxiety                               6606
# Stress                                3502
# Complicated Grief                     3444
# Separation Anxiety                    3163
# Mania                                 3036
# ...

# %%
print(df['first_completed_test_taken'].value_counts(dropna=False))
# Out:
# first_completed_test_taken
# None                                 110206
# Gender Dysphoria                      48356
# Borderline Personality Disorder       46460
# Depression                            39080
# PTSD                                  38237
# Sex Addiction                         32806
# Bipolar Disorder                      30504
# Dissociative Identity Disorder        26663
# Sociopath                             23673
# Narcissistic Personality Disorder     23470
# Postpartum Depression                 20125
# Schizophrenia                         18088
# Relationship Health                   10939
# Binge Eating Disorder                  9431
# Social Anxiety Disorder                8813
# Adult ADHD                             8542
# Anxiety                                6340
# Complicated Grief                      2956
# Eating Disorder                        2807
# Psychosis                              2667
# Mania                                  2661
# ...

# %%
print(df['first_test_taken'].nunique())
# Out:
# 42
